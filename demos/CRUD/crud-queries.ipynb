# %% [markdown]
# ## Install Prerequisites

# %%
! pip install "pymongo[srv]"
# Out:
# Requirement already satisfied: pymongo[srv] in /Users/tom.mccarthy/Projects/tommcc-demos/.venv/lib/python3.10/site-packages (4.2.0)
# Requirement already satisfied: dnspython<3.0.0,>=1.16.0 in /Users/tom.mccarthy/Projects/tommcc-demos/.venv/lib/python3.10/site-packages (from pymongo[srv]) (2.2.1)
# WARNING: You are using pip version 22.0.4; however, version 22.3.1 is available.
# You should consider upgrading via the '/Users/tom.mccarthy/Projects/tommcc-demos/.venv/bin/python -m pip install --upgrade pip' command.

# %%
# Just making sure everything prints cleanly

from pygments.style import Style
from pygments.token import Token
from pygments import highlight
from pygments.lexers import JsonLexer
from pygments.formatters import Terminal256Formatter


class MyStyle(Style):
    styles = {
        Token.String: 'ansigreen',
        Token.Literal: 'ansibrightyellow',
        Token.Keyword: 'ansimagenta',
        Token.Operator: 'ansibrightmagenta'
    }

def pp(doc):
    formatted_json = json.dumps(json.loads(json_util.dumps(doc)), indent=4)
    colorful_json = highlight(formatted_json, JsonLexer(), Terminal256Formatter(style=MyStyle))
    print(colorful_json)

# %% [markdown]
# Add parent to sys path to load config

# %%
import sys
import os
import datetime

sys.path.append("..")

# %%
import pymongo
from bson import json_util
from config import mongo_uri
import json
    
conn = pymongo.MongoClient(mongo_uri)

movies_collection = conn['sample_mflix']['movies']

# %% [markdown]
# ## Create
#
# Create a document

# %%
doc = {
    "fullplot": (
        "When a half-Chechen, half-Russian, brutally tortured immigrant turns up in Hamburg's"
        " Islamic community, laying claim to his father's ill gotten fortune, both German and US"
        " security agencies take a close interest: as the clock ticks down and the stakes rise,"
        " the race is on to establish this most wanted man's true identity - oppressed victim or"
        " destruction-bent extremist? Based on John le Carrè's novel, An Incredibly Clever Title is a"
        " contemporary, cerebral tale of intrigue, love, rivalry, and politics that prickles with"
        " tension right through to its last heart-stopping scene."
    ),
    "imdb": {"rating": 6.8, "votes": 48799, "id": 1972571},
    "year": 2014,
    "plot": (
        "A Chechen Muslim illegally immigrates to Hamburg, where he gets caught in the"
        " international war on terror."
    ),
    "genres": ["Crime", "Drama", "Thriller"],
    "rated": "R",
    "metacritic": 73,
    "title": "An Incredibly Clever Title",
    "lastupdated": "2015-09-04 00:15:39.537000000",
    "languages": ["English", "Turkish"],
    "writers": [
        "Andrew Bovell (screenplay)",
        "John le Carrè (novel)",
        "Stephen Cornwell (additional writing)",
    ],
    "type": "movie",
    "tomatoes": {
        "website": "http://amostwantedmanmovie.com/",
        "viewer": {"rating": 3.5, "numReviews": 35159, "meter": 65},
        "dvd": datetime.datetime(2014, 11, 4, 0, 0),
        "critic": {"rating": 7.4, "numReviews": 181, "meter": 88},
        "lastUpdated": datetime.datetime(2015, 9, 12, 17, 37, 50),
        "consensus": (
            "Smart, subtle, and steadily absorbing, An Incredibly Clever Title proves once again that John"
            " le Carre books make for sharp, thoughtful thrillers."
        ),
        "rotten": 22,
        "production": "Lionsgate/Roadside Attractions",
        "fresh": 159,
    },
    "poster": "https://m.media-amazon.com/images/M/MV5BODY2MTA0MjYzMl5BMl5BanBnXkFtZTgwOTE3NzE4MTE@._V1_SY1000_SX677_AL_.jpg",
    "num_mflix_comments": 0,
    "released": datetime.datetime(2014, 8, 1, 0, 0),
    "awards": {"wins": 2, "nominations": 5, "text": "2 wins & 5 nominations."},
    "countries": ["UK", "USA", "Germany"],
    "cast": ["Grigoriy Dobrygin", "Philip Seymour Hoffman", "Homayoun Ershadi", "Mehdi Dehbi"],
    "directors": ["Anton Corbijn"],
    "runtime": 122,
}

insert_result = movies_collection.insert_one(doc)
print(f"Inserted doc with _id: {insert_result.inserted_id}")
# Out:
# Inserted doc with _id: 63c7ca3fdd38d93f86a2ab9f

# %% [markdown]
# ## Read
#
# Find a single document

# %%
movie = movies_collection.find({"title": "An Incredibly Clever Title"})
pp(movie)
# Out:
# [
#     {
#         "_id": {
#             "$oid": "63c7ca3fdd38d93f86a2ab9f"
#         },
#         "fullplot": "When a half-Chechen, half-Russian, brutally tortured immigrant turns up in Hamburg's Islamic community, laying claim to his father's ill gotten fortune, both German and US security agencies take a close interest: as the clock ticks down and the stakes rise, the race is on to establish this most wanted man's true identity - oppressed victim or destruction-bent extremist? Based on John le Carr\u00e8's novel, An Incredibly Clever Title is a contemporary, cerebral tale of intrigue, love, rivalry, and politics that prickles with tension right through to its last heart-stopping scene.",
#         "imdb": {
#             "rating": 6.8,
#             "votes": 48799,
#             "id": 1972571
#         },
#         "year": 2014,
#         "plot": "A Chechen Muslim illegally immigrates to Hamburg, where he gets caught in the international war on terror.",
#         "genres": [
#             "Crime",
#             "Drama",
#             "Thriller"
#         ],
#         "rated": "R",
#         "metacritic": 73,
#         "title": "An Incredibly Clever Title",
#         "lastupdated": "2015-09-04 00:15:39.537000000",
#         "languages": [
#             "English",
#             "Turkish"
#         ],
#         "writers": [
#             "Andrew Bovell (screenplay)",
#             "John le Carr\u00e8 (novel)",
#             "Stephen Cornwell (additional writing)"
#         ],
#         "type": "movie",
#         "tomatoes": {
#             "website": "http://amostwantedmanmovie.com/",
#             "viewer": {
#                 "rating": 3.5,
#                 "numReviews": 35159,
#                 "meter": 65
#             },
#             "dvd": {
#                 "$date": "2014-11-04T00:00:00Z"
#             },
#             "critic": {
#                 "rating": 7.4,
#                 "numReviews": 181,
#                 "meter": 88
#             },
#             "lastUpdated": {
#                 "$date": "2015-09-12T17:37:50Z"
#             },
#             "consensus": "Smart, subtle, and steadily absorbing, An Incredibly Clever Title proves once again that John le Carre books make for sharp, thoughtful thrillers.",
#             "rotten": 22,
#             "production": "Lionsgate/Roadside Attractions",
#             "fresh": 159
#         },
#         "poster": "https://m.media-amazon.com/images/M/MV5BODY2MTA0MjYzMl5BMl5BanBnXkFtZTgwOTE3NzE4MTE@._V1_SY1000_SX677_AL_.jpg",
#         "num_mflix_comments": 0,
#         "released": {
#             "$date": "2014-08-01T00:00:00Z"
#         },
#         "awards": {
#             "wins": 2,
#             "nominations": 5,
#             "text": "2 wins & 5 nominations."
#         },
#         "countries": [
#             "UK",
#             "USA",
#             "Germany"
#         ],
#         "cast": [
#             "Grigoriy Dobrygin",
#             "Philip Seymour Hoffman",
#             "Homayoun Ershadi",
#             "Mehdi Dehbi"
#         ],
#         "directors": [
#             "Anton Corbijn"
#         ],
#         "runtime": 122
#     }
# ]

# %% [markdown]
# ## Read
#
# More advanced read:
#
# Show me all movies:
# - Rated R and
# - Languages includes English and
# - Genres match both Crime and Thriller
# - Not directed by M Night Shyamalalananaalala
# - Released after 2010
#
# And just return:
# - Title
# - Year
# - Metacritic rating
#
# Sorted by:
# - Metacritic rating descending

# %%
movies = movies_collection.find(
    {
        "rated": "R",
        "languages": "English",
        "genres": {"$all": ["Crime", "Thriller"]},
        "directors": {"$nin": ["M. Night Shyamalan"]},
        "year": {"$gt": 2010},
    },
    {
        "title": 1,
        "year": 1,
        "metacritic": 1,
        "_id": 0

    }
).sort([("metacritic", -1)])

pp(movies)
# Out:
# [
#     {
#         "metacritic": 80,
#         "title": "Miss Bala",
#         "year": 2011
#     },
#     {
#         "year": 2011,
#         "metacritic": 78,
#         "title": "The Guard"
#     },
#     {
#         "year": 2013,
#         "metacritic": 77,
#         "title": "Blue Ruin"
#     },
#     {
#         "year": 2014,
#         "metacritic": 76,
#         "title": "Nightcrawler"
#     },
#     {
#         "year": 2013,
#         "metacritic": 75,
#         "title": "Side Effects"
#     },
#     {
#         "year": 2014,
#         "metacritic": 73,
#         "title": "Cold in July"
#     },
#     {
#         "year": 2015,
#         "metacritic": 73,
#         "title": "A Most Wanted Man"
#     },
#     {
#         "year": 2014,
#         "metacritic": 73,
#         "title": "An Incredibly Clever Title"
#     },
#     {
#         "metacritic": 72,
#         "title": "Headhunters",
#         "year": 2011
#     },
#     {
#         "year": 2014,
#         "metacritic": 71,
#         "title": "The Raid 2"
#     },
#     {
#         "metacritic": 68,
#         "title": "The Place Beyond the Pines",
#         "year": 2012
#     },
#     {
#         "year": 2012,
#         "metacritic": 68,
#         "title": "End of Watch"
#     },
#     {
#         "year": 2012,
#         "metacritic": 68,
#         "title": "Compliance"
#     },
#     {
#         "year": 2012,
#         "metacritic": 64,
#         "title": "Killing Them Softly"
#     },
#     {
#         "metacritic": 64,
#         "title": "Killing Them Softly",
#         "year": 2012
#     },
#     {
#         "metacritic": 63,
#         "title": "The Lincoln Lawyer",
#         "year": 2011
#     },
#     {
#         "year": 2013,
#         "metacritic": 63,
#         "title": "Out of the Furnace"
#     },
#     {
#         "year": 2011,
#         "metacritic": 62,
#         "title": "Killer Joe"
#     },
#     {
#         "metacritic": 59,
#         "title": "Savages",
#         "year": 2012
#     },
#     {
#         "year": 2014,
#         "metacritic": 57,
#         "title": "The Equalizer"
#     },
#     {
#         "metacritic": 55,
#         "title": "Safe",
#         "year": 2012
#     },
#     {
#         "year": 2014,
#         "metacritic": 55,
#         "title": "The Gambler"
#     },
#     {
#         "year": 2013,
#         "metacritic": 54,
#         "title": "The Last Stand"
#     },
#     {
#         "year": 2013,
#         "metacritic": 53,
#         "title": "A Single Shot"
#     },
#     {
#         "year": 2012,
#         "metacritic": 52,
#         "title": "Pusher"
#     },
#     {
#         "year": 2013,
#         "metacritic": 51,
#         "title": "The Call"
#     },
#     {
#         "metacritic": 50,
#         "title": "Child of God",
#         "year": 2013
#     },
#     {
#         "year": 2011,
#         "metacritic": 49,
#         "title": "The Mechanic"
#     },
#     {
#         "metacritic": 49,
#         "title": "Welcome to the Punch",
#         "year": 2013
#     },
#     {
#         "year": 2012,
#         "metacritic": 48,
#         "title": "Bullet to the Head"
#     },
#     {
#         "metacritic": 48,
#         "title": "The Counselor",
#         "year": 2013
#     },
#     {
#         "year": 2013,
#         "metacritic": 47,
#         "title": "In Secret"
#     },
#     {
#         "metacritic": 46,
#         "title": "Sin City: A Dame to Kill For",
#         "year": 2014
#     },
#     {
#         "year": 2011,
#         "metacritic": 44,
#         "title": "Killer Elite"
#     },
#     {
#         "year": 2012,
#         "metacritic": 44,
#         "title": "The Raven"
#     },
#     {
#         "metacritic": 42,
#         "title": "Swerve",
#         "year": 2011
#     },
#     {
#         "year": 2013,
#         "metacritic": 42,
#         "title": "Parker"
#     },
#     {
#         "year": 2013,
#         "metacritic": 42,
#         "title": "The Family"
#     },
#     {
#         "year": 2013,
#         "metacritic": 41,
#         "title": "Machete Kills"
#     },
#     {
#         "year": 2011,
#         "metacritic": 37,
#         "title": "Trespass"
#     },
#     {
#         "year": 2012,
#         "metacritic": 37,
#         "title": "The Samaritan"
#     },
#     {
#         "metacritic": 37,
#         "title": "Cold Comes the Night",
#         "year": 2013
#     },
#     {
#         "metacritic": 37,
#         "title": "Phantom Halo",
#         "year": 2014
#     },
#     {
#         "metacritic": 36,
#         "title": "The Son of No One",
#         "year": 2011
#     },
#     {
#         "metacritic": 36,
#         "title": "Runner Runner",
#         "year": 2013
#     },
#     {
#         "metacritic": 28,
#         "title": "A Good Day to Die Hard",
#         "year": 2013
#     },
#     {
#         "year": 2013,
#         "metacritic": 24,
#         "title": "Line of Duty"
#     },
#     {
#         "title": "The Entitled",
#         "year": 2011
#     },
#     {
#         "title": "Sacrifice",
#         "year": 2011
#     },
#     {
#         "title": "Street Kings 2: Motor City",
#         "year": 2011
#     },
#     {
#         "title": "The River Murders",
#         "year": 2011
#     },
#     {
#         "title": "Border Run",
#         "year": 2012
#     }
# ]

# %% [markdown]
# ## Update
#
# Update a document

# %%
# $set for idempotent update

res = movies_collection.update_one({"title": "An Incredibly Clever Title"}, {"$set": {"year": 2018}})
pp(f"Modified {res.modified_count} documents")
# Out:
# "Modified 1 documents"

# %%
# Not idempotent (could make it so by adding a predicate to check if genre existed already)
res = movies_collection.update_one({"title": "An Incredibly Clever Title"}, {"$push": {"genres": "Comedy"}})
pp(f"Modified {res.modified_count} documents")
# Out:
# "Modified 1 documents"

# %%
# Remove genre from array
res = movies_collection.update_one({"title": "An Incredibly Clever Title"}, {"$pull": {"genres": "Comedy"}})
pp(f"Modified {res.modified_count} documents")
# Out:
# "Modified 0 documents"

# %% [markdown]
# # Delete
# Delete a document

# %%
res = movies_collection.delete_one({"title": "An Incredibly Clever Title"})
pp(f"Deleted {res.deleted_count} documents")
# Out:
# "Deleted 1 documents"
